# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA

#dirname = '/Users/mac/Documents/GitHub/MSc_MNowruzi/'
#fileName = 'olivetti_faces.npy'
#faces = np.load(os.path.join(dirname,fileName))
faces = np.load('olivetti_faces.npy')

# %%
plt.imshow(faces[1], cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
avgFace = np.average(faces, axis=0)
plt.imshow(avgFace, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
X = faces
X = X.reshape((X.shape[0], X.shape[1]**2)) #flattening the image 
X = X - np.average(X, axis=0) #making it zero centered

#printing a sample image to show the effect of zero centering
plt.imshow(X[0].reshape(64,64), cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 63.5, 63.5, -0.5)

# %%
cov_mat = np.cov(X, rowvar = False)

#now calculate eigen values and eigen vectors for cov_mat
cov_mat = np.cov(X, rowvar = False)

#sort the eigenvalues in descending order
sorted_index = np.argsort(eigen_values)[::-1]
 
sorted_eigenvalue = eigen_values[sorted_index]
#similarly sort the eigenvectors 
sorted_eigenvectors = eigen_vectors[:,sorted_index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       4 cov_mat = np.cov(X, rowvar = False)
#       6 #sort the eigenvalues in descending order
# ----> 7 sorted_index = np.argsort(eigen_values)[::-1]
#       9 sorted_eigenvalue = eigen_values[sorted_index]
#      10 #similarly sort the eigenvectors
#
# NameError: name 'eigen_values' is not defined
